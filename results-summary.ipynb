# %% [markdown]
# ## Results Summary:
#
# ### Based on our analysis of the Airbnb Seattle dataset, we can conclude the following:

# %% [markdown]
# ### <u>Question 1</u>: What is the distribution of property listing types in the Seattle Airbnb dataset?
#
# The data shows that the majority of listings (90%) are houses and apartments. In addition, 67% are for the entire home/apartment, while 30% are private rooms, and 3% are shared rooms.

# %% [markdown]
# ![airbnb-21.jpg](attachment:airbnb-21.jpg)

# %% [markdown]
# ![airbnb-13%20copy.jpg](attachment:airbnb-13%20copy.jpg)

# %% [markdown]
# ### <u>Question 2</u>: What is the set of possible amenities and what does the distribution look like?
#
# The distribution of amenities included in all listings is shown in the figure below:

# %% [markdown]
# ![airbnb-19.jpg](attachment:airbnb-19.jpg)

# %% [markdown]
# ### <u>Question 3</u>: How do amenities correlate with average guest feedback scores for a listing?
#
# Based on the results of the analysis, we can see that amenities have a correlation coefficient that ranges from -0.03 to 0.13 with respect to the guest feedback score. The most highly correlated factor with guest feedback scores is the host's designation as a "Superhost" (correlation coefficient 0.24). From this, we can conclude that amenities by themselves are either weakly correlated or uncorrelated with guest review scores.

# %% [markdown]
# ![airbnb-18.jpg](attachment:airbnb-18.jpg)

# %% [markdown]
# ### <u>Question 4</u>: Can we build a predictive model for review scores?
#
# Based on the analysis, we found that a linear model works relatively well for estimating review scores based on available numeric and categorical data. Results of the model are summarized as follows:
#
# - Mean Absolute Error: 2.53
# - Rsquared score-training data:  0.6924
# - Rsquared score-test data:  0.6564
#
# In other words, 65.6% of the variance in review scores is explained by the model.
